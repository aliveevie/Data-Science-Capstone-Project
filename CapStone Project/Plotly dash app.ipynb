# %%
# !pip install dash
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (2.0.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\Ibrahim Abdulkarim\anaconda3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: Flask>=1.0.4 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from dash) (2.0.2)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from dash) (5.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from dash) (5.5.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from dash) (2.0.0)
# Requirement already satisfied: flask-compress in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from dash) (1.10.1)
# Requirement already satisfied: click>=7.1.2 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from Flask>=1.0.4->dash) (8.0.3)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from Flask>=1.0.4->dash) (2.0.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from Flask>=1.0.4->dash) (3.0.3)
# Requirement already satisfied: six in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: brotli in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from flask-compress->dash) (1.0.9)
# Requirement already satisfied: colorama in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from click>=7.1.2->Flask>=1.0.4->dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash) (2.0.1)
# Collecting dash==1.19.0
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\Ibrahim Abdulkarim\anaconda3\python.exe -m pip install --upgrade pip' command.
#   Downloading dash-1.19.0.tar.gz (75 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Flask>=1.0.4 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from dash==1.19.0) (2.0.2)
# Requirement already satisfied: flask-compress in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from dash==1.19.0) (1.10.1)
# Requirement already satisfied: plotly in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from dash==1.19.0) (5.5.0)
# Collecting dash_renderer==1.9.0
#   Downloading dash_renderer-1.9.0.tar.gz (1.0 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dash-core-components==1.15.0
#   Downloading dash_core_components-1.15.0.tar.gz (3.5 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dash-html-components==1.1.2
#   Downloading dash_html_components-1.1.2.tar.gz (188 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting dash-table==4.11.2
#   Downloading dash_table-4.11.2.tar.gz (1.8 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: future in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.2)
# Requirement already satisfied: click>=7.1.2 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from Flask>=1.0.4->dash==1.19.0) (8.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from Flask>=1.0.4->dash==1.19.0) (3.0.3)
# Requirement already satisfied: brotli in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from flask-compress->dash==1.19.0) (1.0.9)
# Requirement already satisfied: six in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from plotly->dash==1.19.0) (8.0.1)
# Requirement already satisfied: colorama in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from click>=7.1.2->Flask>=1.0.4->dash==1.19.0) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Building wheels for collected packages: dash, dash-core-components, dash-html-components, dash-renderer, dash-table
#   Building wheel for dash (setup.py): started
#   Building wheel for dash (setup.py): finished with status 'done'
#   Created wheel for dash: filename=dash-1.19.0-py3-none-any.whl size=84011 sha256=3300b1ddac4bff4bdfed9ce90508e3019efe3d1164bb5ca1b7030b363b759479
#   Stored in directory: c:\users\ibrahim abdulkarim\appdata\local\pip\cache\wheels\e7\27\2f\a9f9bf858843b5365bcb311a80f0b2379737caf4ec50b2ae3a
#   Building wheel for dash-core-components (setup.py): started
#   Building wheel for dash-core-components (setup.py): finished with status 'done'
#   Created wheel for dash-core-components: filename=dash_core_components-1.15.0-py3-none-any.whl size=3527011 sha256=f877027fecb840d0d6faf39071fec32584b34299799480ed929acaafef2088df
#   Stored in directory: c:\users\ibrahim abdulkarim\appdata\local\pip\cache\wheels\e3\e6\0e\759ca580c568aad2436521fa6df67f53a141dc1ab8f040c4c7
#   Building wheel for dash-html-components (setup.py): started
#   Building wheel for dash-html-components (setup.py): finished with status 'done'
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.2-py3-none-any.whl size=427831 sha256=622752ce9199f83a302bbd658691dfc89b19cd5441cabd974c45467db069ab0a
#   Stored in directory: c:\users\ibrahim abdulkarim\appdata\local\pip\cache\wheels\8a\bc\a8\7ad1d354777cfe77413fd7a092e07d7cc82f88f98997f4c463
#   Building wheel for dash-renderer (setup.py): started
#   Building wheel for dash-renderer (setup.py): finished with status 'done'
#   Created wheel for dash-renderer: filename=dash_renderer-1.9.0-py3-none-any.whl size=1014872 sha256=4c29cc19401bf0d3c112b747d0b75e2fea60232f334f5ee83e1150f386160ac6
#   Stored in directory: c:\users\ibrahim abdulkarim\appdata\local\pip\cache\wheels\08\94\09\e11ba8ae5d97e1c8ff5be0ac1f7cf42642eec6ea94ed1e4b44
#   Building wheel for dash-table (setup.py): started
#   Building wheel for dash-table (setup.py): finished with status 'done'
#   Created wheel for dash-table: filename=dash_table-4.11.2-py3-none-any.whl size=1839869 sha256=c6f518ef47436b119de0cb7e636e2b0ec727e0be7e77121daf1a4abac9458376
#   Stored in directory: c:\users\ibrahim abdulkarim\appdata\local\pip\cache\wheels\cc\1d\a0\720dcf854e410eddbe44f8434f4d3a6332fdd085178eeac4f9
# Successfully built dash dash-core-components dash-html-components dash-renderer dash-table
# Installing collected packages: dash-table, dash-renderer, dash-html-components, dash-core-components, dash
#   Attempting uninstall: dash-table
#     Found existing installation: dash-table 5.0.0
#     Uninstalling dash-table-5.0.0:
#       Successfully uninstalled dash-table-5.0.0
#   Attempting uninstall: dash-html-components
#     Found existing installation: dash-html-components 2.0.0
#     Uninstalling dash-html-components-2.0.0:
#       Successfully uninstalled dash-html-components-2.0.0
#   Attempting uninstall: dash-core-components
#     Found existing installation: dash-core-components 2.0.0
#     Uninstalling dash-core-components-2.0.0:
#       Successfully uninstalled dash-core-components-2.0.0
#   Attempting uninstall: dash
#     Found existing installation: dash 2.0.0
#     Uninstalling dash-2.0.0:
#       Successfully uninstalled dash-2.0.0
# Successfully installed dash-1.19.0 dash-core-components-1.15.0 dash-html-components-1.1.2 dash-renderer-1.9.0 dash-table-4.11.2
# Collecting jupyter_dash
#   Using cached jupyter_dash-0.4.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: dash in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: flask in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from jupyter_dash) (2.0.2)
# Collecting ansi2html
#   Downloading ansi2html-1.7.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: ipykernel in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter_dash) (5.3.4)
# Collecting retrying
#   Downloading retrying-1.3.3.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: ipython in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter_dash) (7.22.0)
# Requirement already satisfied: requests in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter_dash) (2.26.0)
# Requirement already satisfied: plotly in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from dash->jupyter_dash) (5.5.0)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: future in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from dash->jupyter_dash) (1.10.1)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: click>=7.1.2 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from flask->jupyter_dash) (8.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from flask->jupyter_dash) (2.0.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from flask->jupyter_dash) (3.0.3)
# Requirement already satisfied: tornado>=4.2 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.0.5)
# Requirement already satisfied: jupyter-client in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipython->jupyter_dash) (52.0.0.post20210125)
# Requirement already satisfied: pygments in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.8.1)
# Requirement already satisfied: colorama in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from ipython->jupyter_dash) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.17.2)
# Requirement already satisfied: backcall in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.17)
# Requirement already satisfied: decorator in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.0.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from requests->jupyter_dash) (2020.12.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.4)
# Requirement already satisfied: six>=1.7.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from retrying->jupyter_dash) (1.15.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from Jinja2>=3.0->flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: wcwidth in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: brotli in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (4.7.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (20.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter_dash) (227)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=f28a634f15a5d87420e0d89edff7ad97e70c4f95ddb33e9acb2ae473c1730612
#   Stored in directory: c:\users\ibrahim abdulkarim\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# Installing collected packages: retrying, ansi2html, jupyter-dash
# Successfully installed ansi2html-1.7.0 jupyter-dash-0.4.0 retrying-1.3.3
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\Ibrahim Abdulkarim\anaconda3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: plotly in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (5.5.0)
# Collecting plotly
#   Downloading plotly-5.6.0-py2.py3-none-any.whl (27.7 MB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from plotly) (1.15.0)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# Successfully installed plotly-5.6.0
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\Ibrahim Abdulkarim\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
spacex_df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv')

# %%
# skeleton Dash app to be completed in this lab, downloaded from:
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/spacex_dash_app.py
# redundant lines commented out

#Import required libraries
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output

# %%
# needs to be run again in a separate cell due to a jupyterdash bug
# notebook hangs if I run the following command 
# !pip install jupyter_dash
# Out:
# Requirement already satisfied: jupyter_dash in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (0.4.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\Ibrahim Abdulkarim\anaconda3\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: flask in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from jupyter_dash) (2.0.2)
# Requirement already satisfied: dash in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: ipython in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter_dash) (7.22.0)
# Requirement already satisfied: ipykernel in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter_dash) (5.3.4)
# Requirement already satisfied: ansi2html in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter_dash) (1.7.0)
# Requirement already satisfied: retrying in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: requests in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter_dash) (2.26.0)
# Requirement already satisfied: plotly in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.6.0)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from dash->jupyter_dash) (1.10.1)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: future in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: click>=7.1.2 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from flask->jupyter_dash) (8.0.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from flask->jupyter_dash) (3.0.3)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from flask->jupyter_dash) (2.0.2)
# Requirement already satisfied: jupyter-client in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.0.5)
# Requirement already satisfied: pickleshare in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: pygments in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.8.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.17.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.17)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipython->jupyter_dash) (52.0.0.post20210125)
# Requirement already satisfied: colorama in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from ipython->jupyter_dash) (0.4.4)
# Requirement already satisfied: decorator in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.0.6)
# Requirement already satisfied: backcall in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from requests->jupyter_dash) (2020.12.5)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.4)
# Requirement already satisfied: six>=1.7.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from retrying->jupyter_dash) (1.15.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from Jinja2>=3.0->flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: wcwidth in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: brotli in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: pyzmq>=13 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (20.0.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (4.7.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ibrahim abdulkarim\appdata\roaming\python\python38\site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ibrahim abdulkarim\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter_dash) (227)

# %%
import plotly.express as px

# Read the airline data into pandas dataframe
# spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# %%
# Create a dash application
app = dash.Dash(__name__) # commented out as we are using JupyterDash instead of dash.Dash


# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                dcc.Dropdown(id='site-dropdown',
                                             options=[
                                                     {'label': 'All Sites', 'value': 'ALL'},
                                                     {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                     {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                     {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                     {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
                                                     ],
                                             value='ALL',
                                             placeholder='Select a Launch Site here',
                                             searchable=True
                                             # style={'width':'80%','padding':'3px','font-size':'20px','text-align-last':'center'}
                                             ),
                                html.Br(),
   # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                dcc.RangeSlider(id='payload-slider',
                                                min=0,
                                                max=10000,
                                                step=1000,
                                                value=[min_payload, max_payload]
                                                ),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
        names='Launch Site', 
        title='Success Count for all launch sites')
        return fig
    else:
        # return the outcomes piechart for a selected site
        filtered_df=spacex_df[spacex_df['Launch Site']== entered_site]
        filtered_df=filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig=px.pie(filtered_df,values='class count',names='class',title=f"Total Success Launches for site {entered_site}")
        return fig
    
# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart',component_property='figure'),
                [Input(component_id='site-dropdown',component_property='value'),
                Input(component_id='payload-slider',component_property='value')])
def scatter(entered_site,payload):
    filtered_df = spacex_df[spacex_df['Payload Mass (kg)'].between(payload[0],payload[1])]
    # thought reusing filtered_df may cause issues, but tried it out of curiosity and it seems to be working fine
    
    if entered_site=='ALL':
        fig=px.scatter(filtered_df,x='Payload Mass (kg)',y='class',color='Booster Version Category',title='Success count on Payload mass for all sites')
        return fig
    else:
        fig=px.scatter(filtered_df[filtered_df['Launch Site']==entered_site],x='Payload Mass (kg)',y='class',color='Booster Version Category',title=f"Success count on Payload mass for site {entered_site}")
        return fig

# Run the app
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [14/Feb/2022 13:48:42] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:48:43] "GET /_dash-component-suites/dash_renderer/polyfill@7.v1_9_0m1644834351.8.7.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:48:43] "GET /_dash-component-suites/dash_renderer/react@16.v1_9_0m1644834351.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:48:43] "GET /_dash-component-suites/dash_renderer/prop-types@15.v1_9_0m1644834351.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:48:43] "GET /_dash-component-suites/dash_renderer/react-dom@16.v1_9_0m1644834351.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:48:43] "GET /_dash-component-suites/dash_html_components/dash_html_components.v1_1_2m1644834354.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:48:43] "GET /_dash-component-suites/dash_core_components/dash_core_components.v1_15_0m1644834358.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:48:43] "GET /_dash-component-suites/dash_renderer/dash_renderer.v1_9_0m1644834351.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:48:43] "GET /_dash-component-suites/dash_core_components/dash_core_components-shared.v1_15_0m1644834358.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:48:44] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:48:44] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:48:44] "GET /_favicon.ico?v=1.19.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:48:44] "GET /_dash-component-suites/dash_core_components/async-dropdown.v1_15_0m1611086576.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:48:44] "GET /_dash-component-suites/dash_core_components/async-graph.v1_15_0m1611086576.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:48:44] "GET /_dash-component-suites/dash_core_components/async-slider.v1_15_0m1611086576.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:48:44] "GET /_dash-component-suites/dash_core_components/async-plotlyjs.v1_15_0m1611086576.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:49:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:49:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:49:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2022 13:49:10] "POST /_dash-update-component HTTP/1.1" 200 -
